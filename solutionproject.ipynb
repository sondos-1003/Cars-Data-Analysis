# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cars = pd.read_csv("C:/Users/dell/Desktop/CarsData1.csv")

# %%
cars.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
cars.shape
# Out:
# (432, 15)

# %%
cars.isnull()
# Out:
#       Make  Model   Type  Origin  DriveTrain   MSRP  Invoice  EngineSize  \
# 0    False  False  False   False       False  False    False       False
# 1    False  False  False   False       False  False    False       False
# 2    False  False  False   False       False  False    False       False
# 3    False  False  False   False       False  False    False       False
# 4    False  False  False   False       False  False    False       False
# ..     ...    ...    ...     ...         ...    ...      ...         ...
# 427  False  False  False   False       False  False    False       False
# 428  False  False  False   False       False  False    False       False
# 429  False  False  False   False       False  False    False       False
# 430  False  False  False   False       False  False    False       False
# 431  False  False  False   False       False  False    False       False
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# ...

# %%
cars.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
cars['Cylinders'].fillna(cars['Cylinders'].mean(),inplace=True)

# %%
cars.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      0
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
cars.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
cars['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Chrysler         15
# Volkswagen       15
# Dodge            13
# Mitsubishi       13
# Jaguar           12
# Hyundai          12
# Volvo            12
# Kia              11
# Pontiac          11
# Mazda            11
# Lexus            11
# Subaru           11
# Lincoln           9
# Buick             9
# Mercury           9
# Cadillac          8
# Infiniti          8
# Suzuki            8
# Saturn            8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# MINI              2
# Scion             2
# Isuzu             2
# Hummer            1
# Name: Make, dtype: int64

# %%
cars[cars['Origin'].isin(['Asia','Europe'])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars[~(cars['Weight']>3000)]
# Out:
#            Make                             Model    Type  Origin DriveTrain  \
# 1         Acura                    RSX Type S 2dr   Sedan    Asia      Front
# 22         Audi  TT 1.8 Quattro 2dr (convertible)  Sports  Europe        All
# 30          NaN                               NaN     NaN     NaN        NaN
# 39          NaN                               NaN     NaN     NaN        NaN
# 45          BMW           Z4 convertible 2.5i 2dr  Sports  Europe       Rear
# ..          ...                               ...     ...     ...        ...
# 406  Volkswagen                      Golf GLS 4dr   Sedan  Europe      Front
# 407  Volkswagen                GTI 1.8T 2dr hatch   Sedan  Europe      Front
# 409  Volkswagen           New Beetle GLS 1.8T 2dr   Sedan  Europe      Front
# 421       Volvo                           S40 4dr   Sedan  Europe      Front
# 430       Volvo                               V40   Wagon  Europe      Front
#
# ...

# %%
cars[(cars['Weight']>4000)]
# Out:
#            Make                           Model    Type  Origin DriveTrain  \
# 0         Acura                             MDX     SUV    Asia        All
# 15         Audi  A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 17         Audi              A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18         Audi                A8 L Quattro 4dr   Sedan  Europe        All
# 20         Audi                        RS 6 4dr  Sports  Europe      Front
# ..          ...                             ...     ...     ...        ...
# 405  Volkswagen                      Touareg V6     SUV  Europe        All
# 415  Volkswagen                     Phaeton 4dr   Sedan  Europe      Front
# 416  Volkswagen                 Phaeton W12 4dr   Sedan  Europe      Front
# 419  Volkswagen                       Passat W8   Wagon  Europe      Front
# 420       Volvo                         XC90 T6     SUV  Europe        All
#
# ...

# %%
cars['MPG_City']=cars['MPG_City'].apply(lambda x:x+5)

# %%
cars['MPG_Highway']=cars['MPG_Highway'].apply(lambda x:x+100)

# %%
cars
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  428.000000  426.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.807512  215.885514   30.060748    26.843458
# std      1.108595    1.558443   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   20.000000    12.000000
# 25%      2.375000    4.000000  165.000000   27.000000    24.000000
# 50%      3.000000    6.000000  210.000000   29.000000    26.000000
# 75%      3.900000    6.000000  255.000000   31.250000    29.000000
# max      8.300000   12.000000  500.000000   70.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %%
newsalary=cars[(cars['Cylinders']>5)]

# %%
newsalary
# Out:
#            Make                    Model    Type  Origin DriveTrain      MSRP  \
# 0         Acura                      MDX     SUV    Asia        All  $36,945
# 3         Acura                   TL 4dr   Sedan    Asia      Front  $33,195
# 4         Acura               3.5 RL 4dr   Sedan    Asia      Front  $43,755
# 5         Acura  3.5 RL w/Navigation 4dr   Sedan    Asia      Front  $46,100
# 6         Acura   NSX coupe 2dr manual S  Sports    Asia       Rear  $89,765
# ..          ...                      ...     ...     ...        ...       ...
# 416  Volkswagen          Phaeton W12 4dr   Sedan  Europe      Front  $75,000
# 419  Volkswagen                Passat W8   Wagon  Europe      Front  $40,235
# 420       Volvo                  XC90 T6     SUV  Europe        All  $41,250
# 425       Volvo              S80 2.9 4dr   Sedan  Europe      Front  $37,730
# 429       Volvo               S80 T6 4dr   Sedan  Europe      Front  $45,210
#
# ...

# %%
sns.catplot(data=cars, x="Horsepower", y="EngineSize", hue="Horsepower" ,kind="point")

# %%
cars[['MSRP','Invoice','MPG_Highway','Weight','Length']].hist(figsize=(10,8),bins=6,color='g')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
corr = cars.corr()
plt.figure(figsize=(20,9))
a = sns.heatmap(corr, annot=True, fmt='.2f')

# %%
plt.rcParams['figure.figsize']=(23,10)
ax = sns.boxplot(x="MPG_City", y="MSRP", data=cars)

# %%
sns.catplot(data=cars, x="Horsepower", y="MSRP", hue="Horsepower" ,kind="point")

# %%
plt.rcParams['figure.figsize']=(10,5)
ax = sns.boxplot(x="Weight", y="Cylinders", data=cars)

# %%
list(cars.columns)
# Out:
# ['Make',
#  'Model',
#  'Type',
#  'Origin',
#  'DriveTrain',
#  'MSRP',
#  'Invoice',
#  'EngineSize',
#  'Cylinders',
#  'Horsepower',
#  'MPG_City',
#  'MPG_Highway',
#  'Weight',
#  'Wheelbase',
#  'Length']

# %%
cars.corr()
# Out:
#              EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# EngineSize     1.000000   0.901727    0.787435 -0.709471    -0.717302
# Cylinders      0.901727   1.000000    0.810185 -0.684152    -0.675823
# Horsepower     0.787435   0.810185    1.000000 -0.676699    -0.647195
# MPG_City      -0.709471  -0.684152   -0.676699  1.000000     0.941021
# MPG_Highway   -0.717302  -0.675823   -0.647195  0.941021     1.000000
# Weight         0.807867   0.741334    0.630796 -0.737966    -0.790989
# Wheelbase      0.636517   0.546644    0.387398 -0.507284    -0.524661
# Length         0.637448   0.546826    0.381554 -0.501526    -0.466092
#
#                Weight  Wheelbase    Length
# EngineSize   0.807867   0.636517  0.637448
# Cylinders    0.741334   0.546644  0.546826
# Horsepower   0.630796   0.387398  0.381554
# MPG_City    -0.737966  -0.507284 -0.501526
# MPG_Highway -0.790989  -0.524661 -0.466092
# Weight       1.000000   0.760703  0.690021
# ...

# %%
cars[['Weight','Wheelbase','Length','Horsepower']].corr()
# Out:
#               Weight  Wheelbase    Length  Horsepower
# Weight      1.000000   0.760703  0.690021    0.630796
# Wheelbase   0.760703   1.000000  0.889195    0.387398
# Length      0.690021   0.889195  1.000000    0.381554
# Horsepower  0.630796   0.387398  0.381554    1.000000

# %%
sns.regplot(x="MPG_Highway", y="MPG_City", data=cars)
plt.ylim(0,)
# Out:
# (0.0, 77.68883963741493)

# %%
cars.describe(include=['object'])
# Out:
#           Make     Model   Type Origin DriveTrain      MSRP   Invoice
# count      428       428    428    428        428       428       428
# unique      38       425      6      3          3       410       425
# top     Toyota  C240 4dr  Sedan   Asia      Front  $21,595   $14,207
# freq        28         2    262    158        226         2         2

# %%
cars['DriveTrain'].unique()
# Out:
# array(['All', 'Front', 'Rear', nan], dtype=object)

# %%
cars_group_one = cars[['Invoice','EngineSize','MSRP']]

# %%
cars_group_one = cars_group_one.groupby(['MSRP'],as_index=False).mean()
cars_group_one
# Out:
#          MSRP  EngineSize
# 0    $10,280          1.6
# 1    $10,539          1.6
# 2    $10,760          1.5
# 3    $10,995          2.2
# 4    $11,155          1.6
# ..        ...         ...
# 405  $86,970          5.0
# 406  $86,995          4.2
# 407  $89,765          3.2
# 408  $90,520          5.0
# 409  $94,820          5.0
#
# [410 rows x 2 columns]

# %%
cars['Make'].dtype
# Out:
# dtype('O')

# %%
cars['EngineSize'].dtype
# Out:
# dtype('float64')

# %%
cars['DriveTrain'].dtype
# Out:
# dtype('O')
